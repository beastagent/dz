# %%
n = ''
stroka = '         Привет! Это я        '
stroka = stroka.strip(' ')
for i in stroka:
    n += i
    print(n)
# Out:
# П
# Пр
# При
# Прив
# Приве
# Привет
# Привет!
# Привет!
# Привет! Э
# Привет! Эт
# Привет! Это
# Привет! Это
# Привет! Это я
