# %%
n = ''
stroka = '         Привет! Это я        '
stroka = stroka.strip(' ')
for i in stroka:
    n += i
    n += '_'
    print(n)
# Out:
# П_
# П_р_
# П_р_и_
# П_р_и_в_
# П_р_и_в_е_
# П_р_и_в_е_т_
# П_р_и_в_е_т_!_
# П_р_и_в_е_т_!_ _
# П_р_и_в_е_т_!_ _Э_
# П_р_и_в_е_т_!_ _Э_т_
# П_р_и_в_е_т_!_ _Э_т_о_
# П_р_и_в_е_т_!_ _Э_т_о_ _
# П_р_и_в_е_т_!_ _Э_т_о_ _я_
